# %%
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)
from wordcloud import wordcloud
# %matplotlib inline
from scipy.special import softmax
import csv
import urllib.request
import tokenize

# %%
df_traintext = pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/offensive/test_text.txt', header=None)
df_traintext.head()
#df_train.columns
# Out:
#                                                    0        1     2
# 0  #ibelieveblaseyford is liar she is fat ugly li...      NaN   NaN
# 1  @user @user @user I got in a pretty deep debat...  kidding  me?!
# 2  ...if you want more shootings and more death, ...      NaN   NaN
# 3  Angels now have 6 runs. Five of them have come...      NaN   NaN
# 4  #Travel #Movies and Unix #Fortune combined  Vi...      NaN   NaN

# %%
# Importing dataset
import pandas as pd

df=pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/offensive/test_text.txt')
print("Shape of data=>",df.shape)
# Out:
# Shape of data=> (859, 3)

# %%
df.isnull().sum()
# Out:
# #ibelieveblaseyford is liar she is fat ugly libreal #snowflake she sold her  herself to get some cash !! From dems and Iran  ! Why she spoke after  #JohnKerryIranMeeting ?      0
# Unnamed: 1                                                                                                                                                                     851
# Unnamed: 2                                                                                                                                                                     856
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# #ibelieveblaseyford is liar she is fat ugly libreal #snowflake she sold her  herself to get some cash !! From dems and Iran  ! Why she spoke after  #JohnKerryIranMeeting ?    0
# Unnamed: 1                                                                                                                                                                     0
# Unnamed: 2                                                                                                                                                                     0
# dtype: int64

# %%
for index,text in enumerate(df[35:40]):
  print('Review %d:\n'%(index+1),text)
# Out:
# Review 1:
#  #ibelieveblaseyford is liar she is fat ugly libreal #snowflake she sold her  herself to get some cash !! From dems and Iran  ! Why she spoke after  #JohnKerryIranMeeting ?
# Review 2:
#  Unnamed: 1
# Review 3:
#  Unnamed: 2

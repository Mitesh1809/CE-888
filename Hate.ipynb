# %%
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)
from wordcloud import wordcloud
# %matplotlib inline
from scipy.special import softmax
import csv
import urllib.request
import tokenize

# %%
df_trainlable = pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/hate/train_labels.txt', header=None)
df_trainlable.head()
#df_train.columns
# Out:
#    0
# 0  0
# 1  1
# 2  1
# 3  1
# 4  0

# %%
df_traintext = pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/hate/train_text.txt')
df_traintext.head()
# Out:
#   @user nice new signage. Are you not concerned by Beatlemania -style hysterical crowds crongregating on you…
# 0  A woman who you fucked multiple times saying y...
# 1  @user @user real talk do you have eyes or were...
# 2  your girlfriend lookin at me like a groupie in...
# 3                        Hysterical woman like @user
# 4       Me flirting- So tell me about your father...

# %%
# Importing dataset
df=pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/hate/train_text.txt')
print("Shape of data=>",df.shape)
# Out:
# Shape of data=> (8992, 1)

# %%
df.isnull().sum()
# Out:
# @user nice new signage. Are you not concerned by Beatlemania -style hysterical crowds crongregating on you…    0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# @user nice new signage. Are you not concerned by Beatlemania -style hysterical crowds crongregating on you…    0
# dtype: int64

# %%
for index,text in enumerate(df[35:40]):
  print('Review %d:\n'%(index+1),text)
# Out:
# Review 1:
#  @user nice new signage. Are you not concerned by Beatlemania -style hysterical crowds crongregating on you…

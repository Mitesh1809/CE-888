# %%
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)
from wordcloud import wordcloud
# %matplotlib inline
from scipy.special import softmax
import csv
import urllib.request
import tokenize

# %%
df_traintext = pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/sentiment/train_text.txt', header=None)
df_train.head()
#df_train.columns
# Out:
#   @user Bono... who cares. Soon people will understand that they gain nothing from following a phony celebrity. Become a Leader of your people instead or help and support your fellow countrymen.  ... Unnamed: 50
# 0  @user Eight years the republicans denied obama...                                                                                                                                                ...         NaN
# 1  @user Get him some line help. He is gonna be j...                                                                                                                                                ...         NaN
# 2                @user @user She is great. Hi Fiona!                                                                                                                                                ...         NaN
# ...

# %%
df_trainlabels=pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/sentiment/train_labels.txt', header=None)
df_train.head()
# Out:
#   @user Bono... who cares. Soon people will understand that they gain nothing from following a phony celebrity. Become a Leader of your people instead or help and support your fellow countrymen.  ... Unnamed: 50
# 0  @user Eight years the republicans denied obama...                                                                                                                                                ...         NaN
# 1  @user Get him some line help. He is gonna be j...                                                                                                                                                ...         NaN
# 2                @user @user She is great. Hi Fiona!                                                                                                                                                ...         NaN
# ...

# %%
df1 = df_traintext
df1.head()
# Out:
#                                                    0    1
# 0  "QT @user In the original draft of the 7th boo...  NaN
# 1  "Ben Smith / Smith (concussion) remains out of...  NaN
# 2  Sorry bout the stream last night I crashed out...  NaN
# 3  Chase Headley's RBI double in the 8th inning o...  NaN
# 4  @user Alciato: Bee will invest 150 million in ...  NaN

# %%
# Importing dataset
df=pd.read_fwf('https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/sentiment/train_text.txt')
print("Shape of data=>",df.shape)
# Out:
# Shape of data=> (45614, 2)

# %%
df1.isnull().sum()
# Out:
# 0        0
# 1    45094
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# "QT @user In the original draft of the 7th book, Remus Lupin survived the Battle of Hogwarts. #HappyBirthdayRemusLupin"    0
# Unnamed: 1                                                                                                                 0
# dtype: int64

# %%
for index,text in enumerate(df[35:40]):
  print('Review %d:\n'%(index+1),text)
# Out:
# Review 1:
#  "QT @user In the original draft of the 7th book, Remus Lupin survived the Battle of Hogwarts. #HappyBirthdayRemusLupin"
# Review 2:
#  Unnamed: 1
